# %%
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt
import matplotlib as mpl

% matplotlib notebook

# %% [markdown]
# Polarization simulation uses a linearly polarized horizontal probe beam.

# %%
w = 1 #frequency of light, set to 1 unit of time
t = np.linspace(0,2*np.pi) #time wave propagates
t
# Out:
# array([ 0.        ,  0.12822827,  0.25645654,  0.38468481,  0.51291309,
#         0.64114136,  0.76936963,  0.8975979 ,  1.02582617,  1.15405444,
#         1.28228272,  1.41051099,  1.53873926,  1.66696753,  1.7951958 ,
#         1.92342407,  2.05165235,  2.17988062,  2.30810889,  2.43633716,
#         2.56456543,  2.6927937 ,  2.82102197,  2.94925025,  3.07747852,
#         3.20570679,  3.33393506,  3.46216333,  3.5903916 ,  3.71861988,
#         3.84684815,  3.97507642,  4.10330469,  4.23153296,  4.35976123,
#         4.48798951,  4.61621778,  4.74444605,  4.87267432,  5.00090259,
#         5.12913086,  5.25735913,  5.38558741,  5.51381568,  5.64204395,
#         5.77027222,  5.89850049,  6.02672876,  6.15495704,  6.28318531])

# %%
n = np.pi/10 #phase difference between fast as slow axis of EO crystal
p = np.pi/4 #angle of QWP
h = np.pi/4 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized

# %%
"""
test = np.linspace(-np.pi,np.pi)
x = np.sin(test)
y = np.cos(test)
plt.plot(x,y)
plt.show()
"""
# Out:
# '\ntest = np.linspace(-np.pi,np.pi)\nx = np.sin(test)\ny = np.cos(test)\nplt.plot(x,y)\nplt.show()\n'

# %%
xeeo = np.real(np.exp(-1.j*w*t)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))
yeeo = np.real(np.exp(-1.j*w*t)*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))
plt.figure()
plt.plot(xeeo,yeeo)
plt.xlabel('Ex')
plt.ylabel('Ey')
plt.title('Polarization after EO crystal')
plt.axis([-1,1,-1,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
xpaaeol = -0.5
xpaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))**2))
ypaaeor = 0.5
ypaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))**2))
plt.bar(xpaaeol,xpaaeo, width = 0.5, align='center')
plt.bar(ypaaeor,ypaaeo, width = 0.5, align='center')
plt.axis([-1,1,0,1])
plt.xlabel('x amplitude (left) and y amplitude (right)')
plt.ylabel('Peak intensity')
plt.title('Polarization amplitudes after EO crystal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
xeq = np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))
yeq = np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))
plt.figure()
plt.plot(xeq,yeq)
plt.xlabel('Ex')
plt.ylabel('Ey')
plt.title('Polarization after QWP')
plt.axis([-1,1,-1,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
xpaaeol = -0.5
xpaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2))
ypaaeor = 0.5
ypaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2))
plt.bar(xpaaeol,xpaaeo, width = 0.5, align='center')
plt.bar(ypaaeor,ypaaeo, width = 0.5, align='center')
plt.axis([-1,1,0,1])
plt.xlabel('x amplitude (left) and y amplitude (right)')
plt.ylabel('Peak intensity')
plt.title('Polarization amplitudes after QWP')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
xpaaeo
# Out:
# 0.046198329925989483

# %%
n = 3*np.pi/10 #phase difference between fast as slow axis of EO crystal
p = 4*np.pi/16 #angle of QWP
h = 5*np.pi/16 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized

plt.figure(figsize = (9,9))

plt.subplot(221, aspect = 'equal')
xeeo = np.real(np.exp(-1.j*w*t)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))
yeeo = np.real(np.exp(-1.j*w*t)*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))
plt.plot(xeeo,yeeo)
plt.xlabel('$E_x$')
plt.ylabel('$E_y$')
plt.title('Polarization after EO crystal')
plt.axis([-1,1,-1,1])


plt.subplot(222, aspect = 'equal')
xpaaeol = -0.25
xpaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))**2))
ypaaeor = 0.25
ypaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))**2))
plt.bar(xpaaeol,xpaaeo, width = 0.25, align='center')
plt.bar(ypaaeor,ypaaeo, width = 0.25, align='center')
plt.axis([-0.5,0.5,0,1])
plt.xlabel('$I_x$ (left) and $I_y$ (right)')
plt.ylabel('Peak intensity')
plt.title('Polarization amplitudes after EO crystal')

plt.subplot(223, aspect = 'equal')
xeq = np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))
yeq = np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))
plt.plot(xeq,yeq)
plt.xlabel('$E_x$')
plt.ylabel('$E_y$')
plt.title('Polarization after QWP')
plt.axis([-1,1,-1,1])

plt.subplot(224, aspect = 'equal')
xpaaql = -0.25
xpaaq = max(np.absolute(np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2))
ypaaqr = 0.25
ypaaq = max(np.absolute(np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2))
plt.bar(xpaaql,xpaaq, width = 0.25, align='center')
plt.bar(ypaaqr,ypaaq, width = 0.25, align='center')
plt.axis([-0.5,0.5,0,1])
plt.xlabel('$I_x$ (left) and $I_y$ (right)')
plt.ylabel('Peak intensity')
plt.title('Polarization amplitudes after QWP')

#plt.subplots_adjust(top=0.92, bottom=0.08, left=0.08, right=0.92, hspace=0.4,wspace=0.4)
plt.tight_layout()
plt.show()
#plt.savefig('eothzmpi10.pdf')
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %%
n = np.pi/10 #phase difference between fast as slow axis of EO crystal
p = np.pi/4 #angle of QWP
h = np.pi/4 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized

ypaaq-xpaaq
# Out:
# 0.92315281580834108

# %%
def dpaaq(n,p,h):
    xpaaq = (((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2
    ypaaq = (((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2 
    return ypaaq - xpaaq

# %%
p = np.pi/4 #angle of QWP
h = np.pi/4 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized
lq = []
for i in range(21):
    n = i*np.pi/10
    lq.append(dpaaq(n,p,h))

# %%
plt.figure()
x = np.linspace(0,2*np.pi,21)
plt.plot(x,lq)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
print(x)
# Out:
# [ 0.          0.31415927  0.62831853  0.9424778   1.25663706  1.57079633
#   1.88495559  2.19911486  2.51327412  2.82743339  3.14159265  3.45575192
#   3.76991118  4.08407045  4.39822972  4.71238898  5.02654825  5.34070751
#   5.65486678  5.96902604  6.28318531]

# %%
lq
# Out:
# [(-1.0000000000000009+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000011+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000007+0j),
#  (-1.0000000000000004+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000011+0j),
#  (-1.0000000000000004+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000004+0j),
#  (-1.0000000000000004+0j),
#  (-1.0000000000000004+0j),
#  (-1.0000000000000011+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000009+0j),
#  (-1.0000000000000009+0j)]

# %%
def dpaaeo(n,h):
    ypaaeo = ((-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))**2
    xpaaeo = ((np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))**2
    return xpaaeo + ypaaeo

# %%
h = np.pi/4 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized
leo = []
for i in range(21):
    n = i*np.pi/10
    leo.append(dpaaeo(n,h))

# %%
plt.figure()
x = np.linspace(0,2*np.pi,21)
plt.plot(x,leo)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
ypaaeo
# Out:
# 0.42633826605056513

# %%
xpaaeo
# Out:
# 0.57301212635400056

# %%
leo
# Out:
# [(1.0000000000000004+0j),
#  (0.95105651629515409+0j),
#  (0.80901699437494778+0j),
#  (0.58778525229247358+0j),
#  (0.30901699437494773+0j),
#  0j,
#  (-0.30901699437494751+0j),
#  (-0.58778525229247292+0j),
#  (-0.80901699437494767+0j),
#  (-0.95105651629515398+0j),
#  (-1.0000000000000004+0j),
#  (-0.95105651629515409+0j),
#  (-0.80901699437494778+0j),
#  (-0.58778525229247336+0j),
#  (-0.30901699437494767+0j),
#  (-1.1102230246251565e-16+0j),
#  (0.30901699437494751+0j),
#  (0.58778525229247325+0j),
#  (0.80901699437494767+0j),
#  (0.95105651629515375+0j),
#  (1.0000000000000004+0j)]

# %%
h = np.pi/4 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized
n = np.pi/4 #phase difference between fast as slow axis of EO crystal

ypaaeo = ((-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))**2
xpaaeo = ((np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))**2

print(ypaaeo, xpaaeo)
# Out:
# (-0.146446609407+0j) (0.853553390593+0j)

# %%
n = 5*np.pi/10 #phase difference between fast as slow axis of EO crystal
p = np.pi/4 #angle of QWP
h = np.pi/4 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized

plt.figure(figsize = (6,3))

plt.subplot(121, aspect = 'equal')
xeeo = np.real(np.exp(-1.j*w*t)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))
yeeo = np.real(np.exp(-1.j*w*t)*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))
plt.plot(xeeo,yeeo)
plt.xlabel('$E_x$')
plt.ylabel('$E_y$')
plt.title('Polarization after EO crystal')
plt.axis([-1,1,-1,1])

"""
plt.subplot(222, aspect = 'equal')
xpaaeol = -0.25
xpaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))**2))
ypaaeor = 0.25
ypaaeo = max(np.absolute(np.real(np.exp(-1.j*w*t)*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))**2))
plt.bar(xpaaeol,xpaaeo, width = 0.25, align='center')
plt.bar(ypaaeor,ypaaeo, width = 0.25, align='center')
plt.axis([-0.5,0.5,0,1])
plt.xlabel('$I_x$ (left) and $I_y$ (right)')
plt.ylabel('Peak intensity')
plt.title('Polarization amplitudes after EO crystal')
"""
plt.subplot(122, aspect = 'equal')
xeq = np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))
yeq = np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))
plt.plot(xeq,yeq)
plt.xlabel('$E_x$')
plt.ylabel('$E_y$')
plt.title('Polarization after QWP')
plt.axis([-1,1,-1,1])
'''
plt.subplot(224, aspect = 'equal')
xpaaql = -0.25
xpaaq = max(np.absolute(np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2))
ypaaqr = 0.25
ypaaq = max(np.absolute(np.real(np.exp(-1.j*w*t)*((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2))
plt.bar(xpaaql,xpaaq, width = 0.25, align='center')
plt.bar(ypaaqr,ypaaq, width = 0.25, align='center')
plt.axis([-0.5,0.5,0,1])
plt.xlabel('$I_x$ (left) and $I_y$ (right)')
plt.ylabel('Peak intensity')
plt.title('Polarization amplitudes after QWP')
'''
#plt.subplots_adjust(top=0.92, bottom=0.08, left=0.08, right=0.92, hspace=0.4,wspace=0.4)
plt.tight_layout()
plt.show()
plt.savefig('eothzoverrotpeakpi2.pdf')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
n = 4.4*np.pi/10 #phase difference between fast as slow axis of EO crystal
p = 4*np.pi/16 #angle of QWP
h = 5*np.pi/16 #angle of fast axis of EO crystal which is pi/4 if the THz wave is horizontally linearly polarized

ypaaeo = ((-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))**2
xpaaeo = ((np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))**2
xpaaq = (((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2
ypaaq = (((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2 

print(ypaaeo,xpaaeo,ypaaq,xpaaq)
# Out:
# (-0.346806717097+0j) (0.534188031683-0.375905056677j) (-0.894254917388+0.331604574082j) (-0.0132601686072-0.0443004825948j)

# %%
ypaaeo = ((-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h))**2
xpaaeo = ((np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2))**2
xpaaq = (((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.cos(p)*np.sin(h)*np.sin(p)+(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2
ypaaq = (((-np.exp(-1.j*np.pi/4)+np.exp(1.j*np.pi/4))*np.cos(p)*(np.exp(1.j*n/2)*np.cos(h)**2+np.exp(-1.j*n/2)*np.sin(h)**2)*np.sin(p)+(-np.exp(-1.j*n/2)+np.exp(1.j*n/2))*np.cos(h)*np.sin(h)*(np.exp(1.j*np.pi/4)*np.cos(p)**2+np.exp(-1.j*np.pi/4)*np.sin(p)**2)))**2
